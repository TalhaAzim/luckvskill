# %% [markdown]
# # Modeling Luck versus Skill

# %%
from scenarios import *
from agents import SimpleAgent
from aggregate_analysis import AggregateAnalysis

skilled_agents = [SimpleAgent(0, FixedSkillLevel(1), constant_value(0.5)) for _ in range(1000)]
AggregateAnalysis(skilled_agents, constant_value(0)).run(1000).plot()
# Out:
# /home/talha/.local/share/virtualenvs/luckvskill-LExpSSGc/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/talha/.local/share/virtualenvs/luckvskill-LExpSSGc/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/talha/.local/share/virtualenvs/luckvskill-LExpSSGc/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
unskilled_agents = [SimpleAgent(0, FixedSkillLevel(0), constant_value(0.5)) for _ in range(1000)]
AggregateAnalysis(unskilled_agents, constant_value(1)).run(1000).plot()
# Out:
# /home/talha/.local/share/virtualenvs/luckvskill-LExpSSGc/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/talha/.local/share/virtualenvs/luckvskill-LExpSSGc/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/talha/.local/share/virtualenvs/luckvskill-LExpSSGc/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
uniform_agents = [SimpleAgent(0, SkillLevel(random.random()), constant_value(.1)) for _ in range(10_000)]
AggregateAnalysis(uniform_agents, random_value(-0.5, 1)).run(10_000).plot()
# Out:
# /home/talha/.local/share/virtualenvs/luckvskill-LExpSSGc/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/talha/.local/share/virtualenvs/luckvskill-LExpSSGc/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/talha/.local/share/virtualenvs/luckvskill-LExpSSGc/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
from single_simulation import SingleSimulation

agent = SimpleAgent(0, SkillLevel(0.5), constant_value(0.25))
SingleSimulation(agent, random_value(-0.5, 1)).run(1000).plot()

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import sympy
#
# ModuleNotFoundError: No module named 'sympy'
